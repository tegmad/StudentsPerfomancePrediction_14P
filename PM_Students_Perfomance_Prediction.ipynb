# %%
import pandas as pd

# %%
df_students = pd.read_csv("Student_performance_data _ (1).csv")

# %%
df_students.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# 1             0  3.042915         1.0
# 2             0  0.112602         4.0
# 3             0  2.054218         3.0
# 4             0  1.288061         4.0

# %% [markdown]
# ---

# %% [markdown]
# # 📄 Dataset Description: Student Academic Performance
#
# This dataset contains demographic, behavioral, and academic details of students, intended for analysis and classification based on academic performance.
#
# ---
#
# ## 🆔 Student Identification
# - **StudentID**: A unique identifier assigned to each student (ranging from **1001 to 3392**).
#
# ---
#
# ## 👥 Demographic Details
# - **Age**: Student age, ranging from **15 to 18 years**.
# - **Gender**:
#   - `0` — Male
#   - `1` — Female
# - **Ethnicity**:
#   - `0` — Caucasian
#   - `1` — African American
#   - `2` — Asian
#   - `3` — Other
# - **ParentalEducation**: Education level of parents:
#   - `0` — None
#   - `1` — High School
#   - `2` — Some College
#   - `3` — Bachelor's
#   - `4` — Higher
#
# ---
#
# ## 📚 Study Habits
# - **StudyTimeWeekly**: Weekly study time in hours (**0 to 20**).
# - **Absences**: Number of school absences (**0 to 30**).
# - **Tutoring**:
#   - `0` — No
#   - `1` — Yes
#
# ---
#
# ## 👨‍👩‍👧 Parental Involvement
# - **ParentalSupport**: Level of parental support:
#   - `0` — None
#   - `1` — Low
#   - `2` — Moderate
#   - `3` — High
#   - `4` — Very High
#
# ---
#
# ## 🎭 Extracurricular Activities
# - **Extracurricular**: Participation in extracurriculars:
#   - `0` — No
#   - `1` — Yes
# - **Sports**: Participation in sports:
#   - `0` — No
#   - `1` — Yes
# - **Music**: Participation in music activities:
#   - `0` — No
#   - `1` — Yes
# - **Volunteering**: Participation in volunteering:
#   - `0` — No
#   - `1` — Yes
#
# ---
#
# ## 🎓 Academic Performance
# - **GPA**: Grade Point Average (scale **2.0 to 4.0**), influenced by study habits, parental support, and extracurricular involvement.
#
# ### 🎯 Target Variable — GradeClass
# Classification of students based on their **GPA**:
# - `0` — Grade **A** (GPA ≥ 3.5)
# - `1` — Grade **B** (3.0 ≤ GPA < 3.5)
# - `2` — Grade **C** (2.5 ≤ GPA < 3.0)
# - `3` — Grade **D** (2.0 ≤ GPA < 2.5)
# - `4` — Grade **F** (GPA < 2.0)
#
# ---

# %%
df_students.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# 1             0  3.042915         1.0
# 2             0  0.112602         4.0
# 3             0  2.054218         3.0
# 4             0  1.288061         4.0

# %% [markdown]
# ## Data Wranling / Cleaning

# %%
df_students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
df_students.isna().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
df_students.duplicated().sum()
# Out:
# 0

# %%
df_students = df_students.drop(['StudentID'],axis=1)

# %% [markdown]
# ## EDA - Exploratory Data Analyses : Find some trends, anomalies

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

# %%
df_students.head()
# Out:
#    Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 0   17       1          0                  2        19.833723         7
# 1   18       0          0                  1        15.408756         0
# 2   15       0          2                  3         4.210570        26
# 3   17       1          0                  3        10.028829        14
# 4   17       1          0                  2         4.672495        17
#
#    Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering  \
# 0         1                2                0       0      1             0
# 1         0                1                0       0      0             0
# 2         0                2                0       0      0             0
# 3         0                3                1       0      0             0
# 4         1                3                0       0      0             0
#
#         GPA  GradeClass
# 0  2.929196         2.0
# 1  3.042915         1.0
# 2  0.112602         4.0
# 3  2.054218         3.0
# 4  1.288061         4.0

# %% [markdown]
# ## Task 1: Seeing the proportion of Data in the Data set

# %%
df_by_gender = df_students.groupby('Gender')['Gender'].count().reset_index(name='count')
df_by_gender['Gender'] = df_by_gender['Gender'].map({0:'Male', 1:'Female'})


fig = px.pie(
    df_by_gender,
    names='Gender',
    values='count',
    color='Gender',
    color_discrete_map={'Male': 'blue', 'Female': 'deeppink'},
    title='Gender Distribution'
)

fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_layout(
    width = 800,
    height = 600,
    showlegend=True)
fig.show()

# %%
df_by_gender.style.background_gradient()
# Out:
# <style type="text/css">
# #T_38a40_row0_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_38a40_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_38a40">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38a40_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_38a40_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38a40_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38a40_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_38a40_row0_col1" class="data row0 col1" >1170</td>
#     </tr>
#     <tr>
#       <th id="T_38a40_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_38a40_row1_col0" class="data row1 col0" >Female</td>
#       <td id="T_38a40_row1_col1" class="data row1 col1" >1222</td>
#     </tr>
#   </tbody>
# </table>

# %%
def gender(x):
    if x == 0:
        return 'Male'
    else:
        return 'Female'
df_students['Gender_'] = df_students['Gender'].apply(gender)

# %%
import plotly.express as px

fig = px.histogram(
    df_students,
    x='Age',                  
    color='Gender_',            
    nbins=20,                  
    title='Age Distribution of Students by Gender',
    color_discrete_map={'Male': 'blue', 'Female': 'deeppink'},  
    barmode='group',           
    text_auto=True             
)

fig.update_layout(
    width=1000,
    height=600,
    xaxis_title='Age',
    yaxis_title='Number of Students',
    bargap=0.1
)

fig.show()

# %%
# Destribution by Etnicity

df_ethnicity = df_students[['Ethnicity','Age','Gender','ParentalEducation','Absences','GPA','Volunteering']]
df_ethnicity['Ethnicity'] = df_ethnicity['Ethnicity'].map({0:'Caucasian',1:'African American',2:'Asian',3:'Other'})
df_ethnicity.head()
# Out:
# /var/folders/mf/0x7x5kpj2kx0tq4hcfm_z4p80000gn/T/ipykernel_11128/3788699464.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Ethnicity  Age  Gender  ParentalEducation  Absences       GPA  Volunteering
# 0  Caucasian   17       1                  2         7  2.929196             0
# 1  Caucasian   18       0                  1         0  3.042915             0
# 2      Asian   15       0                  3        26  0.112602             0
# 3  Caucasian   17       1                  3        14  2.054218             0
# 4  Caucasian   17       1                  2        17  1.288061             0

# %%
df_by_ethnicity = df_ethnicity.groupby(['Ethnicity','Age'])[['Gender']].count().reset_index()
df_by_ethnicity = df_by_ethnicity.rename(columns={'Gender':'Count'})
df_by_ethnicity.sort_values(by='Ethnicity').style.background_gradient(subset=['Count'],cmap='Reds')
# Out:
# <style type="text/css">
# #T_87bc2_row0_col2 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_87bc2_row1_col2, #T_87bc2_row6_col2 {
#   background-color: #fcaf93;
#   color: #000000;
# }
# #T_87bc2_row2_col2 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_87bc2_row3_col2 {
#   background-color: #fcc1a8;
#   color: #000000;
# }
# #T_87bc2_row4_col2 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_87bc2_row5_col2 {
#   background-color: #fcc3ab;
#   color: #000000;
# }
# #T_87bc2_row7_col2 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_87bc2_row8_col2 {
#   background-color: #6f020e;
#   color: #f1f1f1;
# }
# #T_87bc2_row9_col2 {
#   background-color: #71020e;
#   color: #f1f1f1;
# }
# #T_87bc2_row10_col2 {
#   background-color: #900a12;
#   color: #f1f1f1;
# }
# #T_87bc2_row11_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_87bc2_row12_col2 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_87bc2_row13_col2 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_87bc2_row14_col2 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_87bc2_row15_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_87bc2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87bc2_level0_col0" class="col_heading level0 col0" >Ethnicity</th>
#       <th id="T_87bc2_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_87bc2_level0_col2" class="col_heading level0 col2" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87bc2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87bc2_row0_col0" class="data row0 col0" >African American</td>
#       <td id="T_87bc2_row0_col1" class="data row0 col1" >15</td>
#       <td id="T_87bc2_row0_col2" class="data row0 col2" >135</td>
#     </tr>
#     <tr>
#       <th id="T_87bc2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_87bc2_row1_col0" class="data row1 col0" >African American</td>
#       <td id="T_87bc2_row1_col1" class="data row1 col1" >16</td>
#       <td id="T_87bc2_row1_col2" class="data row1 col2" >122</td>
#     </tr>
#     <tr>
#       <th id="T_87bc2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_87bc2_row2_col0" class="data row2 col0" >African American</td>
#       <td id="T_87bc2_row2_col1" class="data row2 col1" >17</td>
#       <td id="T_87bc2_row2_col2" class="data row2 col2" >128</td>
#     </tr>
#     <tr>
#       <th id="T_87bc2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_87bc2_row3_col0" class="data row3 col0" >African American</td>
#       <td id="T_87bc2_row3_col1" class="data row3 col1" >18</td>
#       <td id="T_87bc2_row3_col2" class="data row3 col2" >108</td>
#     </tr>
#     <tr>
#       <th id="T_87bc2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_87bc2_row4_col0" class="data row4 col0" >Asian</td>
#       <td id="T_87bc2_row4_col1" class="data row4 col1" >15</td>
#       <td id="T_87bc2_row4_col2" class="data row4 col2" >125</td>
#     </tr>
#     <tr>
#       <th id="T_87bc2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_87bc2_row5_col0" class="data row5 col0" >Asian</td>
#       <td id="T_87bc2_row5_col1" class="data row5 col1" >16</td>
#       <td id="T_87bc2_row5_col2" class="data row5 col2" >106</td>
#     </tr>
#     <tr>
#       <th id="T_87bc2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_87bc2_row6_col0" class="data row6 col0" >Asian</td>
#       <td id="T_87bc2_row6_col1" class="data row6 col1" >17</td>
#       <td id="T_87bc2_row6_col2" class="data row6 col2" >122</td>
#     </tr>
#     <tr>
#       <th id="T_87bc2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_87bc2_row7_col0" class="data row7 col0" >Asian</td>
#       <td id="T_87bc2_row7_col1" class="data row7 col1" >18</td>
#       <td id="T_87bc2_row7_col2" class="data row7 col2" >117</td>
#     </tr>
#     <tr>
#       <th id="T_87bc2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_87bc2_row8_col0" class="data row8 col0" >Caucasian</td>
#       <td id="T_87bc2_row8_col1" class="data row8 col1" >15</td>
#       <td id="T_87bc2_row8_col2" class="data row8 col2" >305</td>
#     </tr>
#     <tr>
#       <th id="T_87bc2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_87bc2_row9_col0" class="data row9 col0" >Caucasian</td>
#       <td id="T_87bc2_row9_col1" class="data row9 col1" >16</td>
#       <td id="T_87bc2_row9_col2" class="data row9 col2" >304</td>
#     </tr>
#     <tr>
#       <th id="T_87bc2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_87bc2_row10_col0" class="data row10 col0" >Caucasian</td>
#       <td id="T_87bc2_row10_col1" class="data row10 col1" >17</td>
#       <td id="T_87bc2_row10_col2" class="data row10 col2" >288</td>
#     </tr>
#     <tr>
#       <th id="T_87bc2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_87bc2_row11_col0" class="data row11 col0" >Caucasian</td>
#       <td id="T_87bc2_row11_col1" class="data row11 col1" >18</td>
#       <td id="T_87bc2_row11_col2" class="data row11 col2" >310</td>
#     </tr>
#     <tr>
#       <th id="T_87bc2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_87bc2_row12_col0" class="data row12 col0" >Other</td>
#       <td id="T_87bc2_row12_col1" class="data row12 col1" >15</td>
#       <td id="T_87bc2_row12_col2" class="data row12 col2" >65</td>
#     </tr>
#     <tr>
#       <th id="T_87bc2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_87bc2_row13_col0" class="data row13 col0" >Other</td>
#       <td id="T_87bc2_row13_col1" class="data row13 col1" >16</td>
#       <td id="T_87bc2_row13_col2" class="data row13 col2" >61</td>
#     </tr>
#     <tr>
#       <th id="T_87bc2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_87bc2_row14_col0" class="data row14 col0" >Other</td>
#       <td id="T_87bc2_row14_col1" class="data row14 col1" >17</td>
#       <td id="T_87bc2_row14_col2" class="data row14 col2" >49</td>
#     </tr>
#     <tr>
#       <th id="T_87bc2_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_87bc2_row15_col0" class="data row15 col0" >Other</td>
#       <td id="T_87bc2_row15_col1" class="data row15 col1" >18</td>
#       <td id="T_87bc2_row15_col2" class="data row15 col2" >47</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_by_ethnicity_avg_GPA = df_ethnicity.groupby(['Ethnicity','Age'])['GPA'].mean().reset_index(name='Avg_GPA')
df_combined = df_by_ethnicity.merge(df_by_ethnicity_avg_GPA,on=['Ethnicity','Age'])

df_combined.style.background_gradient(subset=['Count','Avg_GPA'],cmap='Blues')
# Out:
# <style type="text/css">
# #T_f0297_row0_col2 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_f0297_row0_col3 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_f0297_row1_col2, #T_f0297_row6_col2 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_f0297_row1_col3 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_f0297_row2_col2 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_f0297_row2_col3 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_f0297_row3_col2 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_f0297_row3_col3 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_f0297_row4_col2, #T_f0297_row15_col3 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_f0297_row4_col3, #T_f0297_row15_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f0297_row5_col2 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_f0297_row5_col3, #T_f0297_row9_col3 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_f0297_row6_col3 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_f0297_row7_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_f0297_row7_col3, #T_f0297_row11_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f0297_row8_col2 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_f0297_row8_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_f0297_row9_col2 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_f0297_row10_col2 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_f0297_row10_col3 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_f0297_row11_col3 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_f0297_row12_col2 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_f0297_row12_col3 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_f0297_row13_col2 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_f0297_row13_col3 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_f0297_row14_col2 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_f0297_row14_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f0297">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0297_level0_col0" class="col_heading level0 col0" >Ethnicity</th>
#       <th id="T_f0297_level0_col1" class="col_heading level0 col1" >Age</th>
#       <th id="T_f0297_level0_col2" class="col_heading level0 col2" >Count</th>
#       <th id="T_f0297_level0_col3" class="col_heading level0 col3" >Avg_GPA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0297_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f0297_row0_col0" class="data row0 col0" >African American</td>
#       <td id="T_f0297_row0_col1" class="data row0 col1" >15</td>
#       <td id="T_f0297_row0_col2" class="data row0 col2" >135</td>
#       <td id="T_f0297_row0_col3" class="data row0 col3" >1.955663</td>
#     </tr>
#     <tr>
#       <th id="T_f0297_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f0297_row1_col0" class="data row1 col0" >African American</td>
#       <td id="T_f0297_row1_col1" class="data row1 col1" >16</td>
#       <td id="T_f0297_row1_col2" class="data row1 col2" >122</td>
#       <td id="T_f0297_row1_col3" class="data row1 col3" >1.935769</td>
#     </tr>
#     <tr>
#       <th id="T_f0297_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f0297_row2_col0" class="data row2 col0" >African American</td>
#       <td id="T_f0297_row2_col1" class="data row2 col1" >17</td>
#       <td id="T_f0297_row2_col2" class="data row2 col2" >128</td>
#       <td id="T_f0297_row2_col3" class="data row2 col3" >1.897900</td>
#     </tr>
#     <tr>
#       <th id="T_f0297_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f0297_row3_col0" class="data row3 col0" >African American</td>
#       <td id="T_f0297_row3_col1" class="data row3 col1" >18</td>
#       <td id="T_f0297_row3_col2" class="data row3 col2" >108</td>
#       <td id="T_f0297_row3_col3" class="data row3 col3" >2.004481</td>
#     </tr>
#     <tr>
#       <th id="T_f0297_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f0297_row4_col0" class="data row4 col0" >Asian</td>
#       <td id="T_f0297_row4_col1" class="data row4 col1" >15</td>
#       <td id="T_f0297_row4_col2" class="data row4 col2" >125</td>
#       <td id="T_f0297_row4_col3" class="data row4 col3" >1.732035</td>
#     </tr>
#     <tr>
#       <th id="T_f0297_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f0297_row5_col0" class="data row5 col0" >Asian</td>
#       <td id="T_f0297_row5_col1" class="data row5 col1" >16</td>
#       <td id="T_f0297_row5_col2" class="data row5 col2" >106</td>
#       <td id="T_f0297_row5_col3" class="data row5 col3" >1.905306</td>
#     </tr>
#     <tr>
#       <th id="T_f0297_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f0297_row6_col0" class="data row6 col0" >Asian</td>
#       <td id="T_f0297_row6_col1" class="data row6 col1" >17</td>
#       <td id="T_f0297_row6_col2" class="data row6 col2" >122</td>
#       <td id="T_f0297_row6_col3" class="data row6 col3" >1.949958</td>
#     </tr>
#     <tr>
#       <th id="T_f0297_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f0297_row7_col0" class="data row7 col0" >Asian</td>
#       <td id="T_f0297_row7_col1" class="data row7 col1" >18</td>
#       <td id="T_f0297_row7_col2" class="data row7 col2" >117</td>
#       <td id="T_f0297_row7_col3" class="data row7 col3" >2.111428</td>
#     </tr>
#     <tr>
#       <th id="T_f0297_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f0297_row8_col0" class="data row8 col0" >Caucasian</td>
#       <td id="T_f0297_row8_col1" class="data row8 col1" >15</td>
#       <td id="T_f0297_row8_col2" class="data row8 col2" >305</td>
#       <td id="T_f0297_row8_col3" class="data row8 col3" >1.922356</td>
#     </tr>
#     <tr>
#       <th id="T_f0297_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f0297_row9_col0" class="data row9 col0" >Caucasian</td>
#       <td id="T_f0297_row9_col1" class="data row9 col1" >16</td>
#       <td id="T_f0297_row9_col2" class="data row9 col2" >304</td>
#       <td id="T_f0297_row9_col3" class="data row9 col3" >1.904875</td>
#     </tr>
#     <tr>
#       <th id="T_f0297_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f0297_row10_col0" class="data row10 col0" >Caucasian</td>
#       <td id="T_f0297_row10_col1" class="data row10 col1" >17</td>
#       <td id="T_f0297_row10_col2" class="data row10 col2" >288</td>
#       <td id="T_f0297_row10_col3" class="data row10 col3" >1.902125</td>
#     </tr>
#     <tr>
#       <th id="T_f0297_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f0297_row11_col0" class="data row11 col0" >Caucasian</td>
#       <td id="T_f0297_row11_col1" class="data row11 col1" >18</td>
#       <td id="T_f0297_row11_col2" class="data row11 col2" >310</td>
#       <td id="T_f0297_row11_col3" class="data row11 col3" >1.777434</td>
#     </tr>
#     <tr>
#       <th id="T_f0297_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f0297_row12_col0" class="data row12 col0" >Other</td>
#       <td id="T_f0297_row12_col1" class="data row12 col1" >15</td>
#       <td id="T_f0297_row12_col2" class="data row12 col2" >65</td>
#       <td id="T_f0297_row12_col3" class="data row12 col3" >1.988047</td>
#     </tr>
#     <tr>
#       <th id="T_f0297_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f0297_row13_col0" class="data row13 col0" >Other</td>
#       <td id="T_f0297_row13_col1" class="data row13 col1" >16</td>
#       <td id="T_f0297_row13_col2" class="data row13 col2" >61</td>
#       <td id="T_f0297_row13_col3" class="data row13 col3" >1.868187</td>
#     </tr>
#     <tr>
#       <th id="T_f0297_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f0297_row14_col0" class="data row14 col0" >Other</td>
#       <td id="T_f0297_row14_col1" class="data row14 col1" >17</td>
#       <td id="T_f0297_row14_col2" class="data row14 col2" >49</td>
#       <td id="T_f0297_row14_col3" class="

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_ethnicity_2 = df_students.copy()
df_ethnicity_2['Ethnicity name'] = df_ethnicity_2['Ethnicity'].map({
    0: 'Caucasian', 1: 'African American', 2: 'Asian', 3: 'Other'
})
df_ethnicity_2 = df_ethnicity_2.groupby(
    ['Ethnicity name', 'Gender_', 'GradeClass']
)['Age'].count().reset_index()
df_ethnicity_2 = df_ethnicity_2.rename(columns={'Age': 'Count'})
df_ethnicity_2['Grade Explanation'] = df_ethnicity_2['GradeClass'].map({
    0: '>=3.5', 1: '3 ~ 3.5', 2: '2.5 ~ 3.0', 3: '2 ~ 2.5', 4: '<=2.0'
})

ethnicity_groups = ['African American', 'Asian', 'Caucasian', 'Other']
colors = {'Male': 'blue', 'Female': 'deeppink'}

fig, axes = plt.subplots(2, 2, figsize=(16, 12))
axes = axes.flatten()  

for i, ethnicity in enumerate(ethnicity_groups):
    ax = axes[i]
    subset = df_ethnicity_2[df_ethnicity_2['Ethnicity name'] == ethnicity]

    barplot = sns.barplot(
        x='Grade Explanation',
        y='Count',
        hue='Gender_',
        data=subset,
        palette=colors,
        ax=ax
    )

    ax.set_title(f'{ethnicity} Students by Grade and Gender')
    ax.set_xlabel('Grade')
    ax.set_ylabel('Count')
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
    ax.legend(title='Gender')

    for container in barplot.containers:
        barplot.bar_label(container, fmt='%d', label_type='edge', fontsize=9, padding=2)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/mf/0x7x5kpj2kx0tq4hcfm_z4p80000gn/T/ipykernel_11128/1538472168.py:41: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#
# /var/folders/mf/0x7x5kpj2kx0tq4hcfm_z4p80000gn/T/ipykernel_11128/1538472168.py:41: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#
# /var/folders/mf/0x7x5kpj2kx0tq4hcfm_z4p80000gn/T/ipykernel_11128/1538472168.py:41: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#
# /var/folders/mf/0x7x5kpj2kx0tq4hcfm_z4p80000gn/T/ipykernel_11128/1538472168.py:41: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %%
df_students.head()
# Out:
#    Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 0   17       1          0                  2        19.833723         7
# 1   18       0          0                  1        15.408756         0
# 2   15       0          2                  3         4.210570        26
# 3   17       1          0                  3        10.028829        14
# 4   17       1          0                  2         4.672495        17
#
#    Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering  \
# 0         1                2                0       0      1             0
# 1         0                1                0       0      0             0
# 2         0                2                0       0      0             0
# 3         0                3                1       0      0             0
# 4         1                3                0       0      0             0
#
#         GPA  GradeClass Gender_
# 0  2.929196         2.0  Female
# 1  3.042915         1.0    Male
# 2  0.112602         4.0    Male
# 3  2.054218         3.0  Female
# 4  1.288061         4.0  Female

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,6))

male_df = df_students[df_students['Gender_'] == 'Male']
female_df = df_students[df_students['Gender_'] == 'Female']

sns.histplot(x='GPA', data=female_df, kde=True, color='deeppink', label='Female')
sns.histplot(x='GPA', data=male_df, kde=True, color='blue', label='Male')

female_mean = female_df['GPA'].mean()
female_median = female_df['GPA'].median()
male_mean = male_df['GPA'].mean()
male_median = male_df['GPA'].median()

plt.axvline(female_mean, color='deeppink', linestyle='--', linewidth=2, 
            label=f'Female Mean: {female_mean:.2f}')
plt.axvline(female_median, color='deeppink', linestyle=':', linewidth=2, 
            label=f'Female Median: {female_median:.2f}')
plt.axvline(male_mean, color='blue', linestyle='--', linewidth=2, 
            label=f'Male Mean: {male_mean:.2f}')
plt.axvline(male_median, color='blue', linestyle=':', linewidth=2, 
            label=f'Male Median: {male_median:.2f}')

plt.legend()
plt.xlim()
plt.tight_layout()
plt.show()

# %%
import seaborn as sns 

plt.figure(figsize=(12,6))

sns.scatterplot(
    data=df_students, 
    x='Absences', 
    y='GPA',
    color= 'red',
    alpha=0.7
)

plt.title('GPA vs Absence')
plt.xlabel('Absences')
plt.ylabel('GPA')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns 

plt.figure(figsize=(12,6))

sns.scatterplot(
    data=df_students, 
    x='StudyTimeWeekly', 
    y='GPA', 
    hue='Gender_', 
    palette={'Male': 'blue', 'Female': 'deeppink'},
    alpha=0.7
)

plt.title('GPA vs Gender')
plt.xlabel('Absences')
plt.ylabel('GPA')
plt.legend(title='Gender')
plt.tight_layout()
plt.show()

# %%
boxplot_task = df_students
boxplot_task['ParentalSupport name'] = boxplot_task['ParentalSupport'].map({0:'None',1:'Low',2:'Moderate',3:"High",4:'Very High'})
boxplot_task = boxplot_task.sort_values(by='ParentalSupport',ascending=True)

plt.figure(figsize=(8,6))

sns.boxplot(x='ParentalSupport name',y='GPA',data=boxplot_task,hue='ParentalSupport',legend=False)


plt.title('GPA vs Parent Education Level')
plt.xlabel('Parent Support')
plt.ylabel("Student's GPA")
plt.show()

# %%
plt.figure(figsize=(8,6))

sns.boxplot(x='ParentalEducation name',y='GPA',data=boxplot_task,hue='ParentalEducation name')


plt.title('GPA vs Parent Education Level')
plt.xlabel('Parent Education Level')
plt.ylabel("Student's GPA")
plt.show()

# %% [markdown]
# ## Building ML

# %%
df_students.drop(['Gender_','Ethnicity name','ParentalEducation name','ParentalSupport name'],axis=1,inplace=True)

# %%
numeric_df = df_students.select_dtypes(include='number')

corr_matrix = numeric_df.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.tight_layout()
plt.show()
